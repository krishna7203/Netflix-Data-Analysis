# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
data=pd.read_csv("C:/Users/kbari/Downloads/netflix1.csv")

# %%
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
data.dropna(subset=['director','country'],inplace=True)
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
data['date_added']=pd.to_datetime(data['date_added'])
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# dtype: object

# %%
#Count the number of Movies and TV Shows
type_counts=data['type'].value_counts()
type_counts
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
#Plotting the Distribution
plt.figure(figsize=(8,6))
sns.barplot(x=type_counts.index,y=type_counts.values,palette='Set2')
plt.title('Movies vs Tv Shows')
plt.xlabel('type')
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\kbari\AppData\Local\Temp\ipykernel_24380\2766590392.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=type_counts.index,y=type_counts.values,palette='Set2')

# %%
#Feature Engineering
data['genres']=data['listed_in'].apply(lambda x :x.split(','))
all_genres=sum(data['genres'],[])
all_genres
# Out:
# ['Documentaries',
#  'Crime TV Shows',
#  ' International TV Shows',
#  ' TV Action & Adventure',
#  'TV Dramas',
#  ' TV Horror',
#  ' TV Mysteries',
#  'Children & Family Movies',
#  ' Comedies',
#  'Dramas',
#  ' Independent Movies',
#  ' International Movies',
#  'British TV Shows',
#  ' Reality TV',
#  'Comedies',
#  ' Dramas',
#  'Children & Family Movies',
#  ' Comedies',
#  ' Music & Musicals',
#  'Dramas',
#  ' International Movies',
#  'Children & Family Movies',
#  ' Music & Musicals',
#  'Children & Family Movies',
#  ' Comedies',
#  'Children & Family Movies',
#  ' Comedies',
#  'Dramas',
#  ' International Movies',
#  ' Music & Musicals',
#  'Movies',
#  'Movies',
#  'Movies',
#  'Comedies',
#  'Docuseries',
#  ' Reality TV',
#  'British TV Shows',
#  ' Crime TV Shows',
#  ' Docuseries',
#  'Children & Family Movies',
#  "Kids' TV",
#  "Kids' TV",
#  "Kids' TV",
#  'Children & Family Movies',
#  'Crime TV Shows',
#  ' International TV Shows',
# ...

# %%
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %%
#Counting the number of most common genres
genre_counts=pd.Series(all_genres).value_counts()
genre_counts
# Out:
#  International Movies        2624
# Dramas                       1599
# Comedies                     1210
# Action & Adventure            859
# Documentaries                 829
#                              ...
# Romantic Movies                 3
# Spanish-Language TV Shows       2
# LGBTQ Movies                    1
# TV Sci-Fi & Fantasy             1
# Sports Movies                   1
# Name: count, Length: 73, dtype: int64

# %%
#PLotting the Most common Genres on Netflix
plt.figure(figsize=(10,15))
sns.barplot(x=genre_counts.values,y=genre_counts.index,palette='Set3')
plt.title('Most Common Genres on Netflix')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.show()
# Out:
# C:\Users\kbari\AppData\Local\Temp\ipykernel_24380\1170872813.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genre_counts.values,y=genre_counts.index,palette='Set3')

# %%
#Extracting year and month from 'date_added'
data['year_added']=data['date_added'].dt.year
data['month_added']=data['date_added'].dt.month
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %%
# Plotting Content Added over Years
plt.figure(figsize=(10,6))
sns.countplot(x='year_added',data=data,palette='coolwarm')
plt.title('Content Added Over Time')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\kbari\AppData\Local\Temp\ipykernel_24380\2844670753.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='year_added',data=data,palette='coolwarm')

# %%
#Counting titles by Director
filtered_data = data[data['director'] != 'Not Given']
top_directors=filtered_data['director'].value_counts().head(10)
top_directors
# Out:
# director
# Rajiv Chilaka             20
# Raúl Campos, Jan Suter    18
# Alastair Fothergill       18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Jay Chapman               12
# Martin Scorsese           12
# Name: count, dtype: int64

# %%
#Plotting Top Directors
plt.figure(figsize=(10,6))
sns.barplot(x=top_directors.values,y=top_directors.index,palette='Blues_d')
plt.title('Top 10 Directors with the Most Titles')
plt.xlabel('Number of Titles')
plt.ylabel('Director')
plt.show()
# Out:
# C:\Users\kbari\AppData\Local\Temp\ipykernel_24380\526121216.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_directors.values,y=top_directors.index,palette='Blues_d')

# %%
#Generating word cloud of Movie Titles
movie_titles=data[data['type']=='Movie']['title']
wordcloud=WordCloud(width=800,height=400,background_color='black').generate(' '.join(movie_titles))

# %%
#Plotting word cloud of Movie Titles
plt.figure(figsize=(10,6))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Number of genres per title
data['genre_count']=data['genres'].apply(lambda x: len(str(x).split(',')))
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %%
data['duration_num']=None
movies=data['type']=='Movie'
data.loc[movies,'duration_num']=(data.loc[movies,'duration'].str.split().str[0].astype(float))
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %%
features = data[['release_year', 'duration_num', 'genre_count']].dropna()

# %%
features
# Out:
#       release_year duration_num  genre_count
# 0             2020         90.0            1
# 3             2021         91.0            2
# 4             1993        125.0            3
# 6             2021        104.0            2
# 7             2019         87.0            3
# ...            ...          ...          ...
# 8702          1983        103.0            3
# 8707          2016         75.0            3
# 8716          2018        136.0            3
# 8763          2015         89.0            2
# 8783          2015         78.0            1
#
# [6126 rows x 3 columns]

# %%
sns.histplot(data['release_year'], bins=20)
plt.title('Distribution of Release Year')
plt.show()
